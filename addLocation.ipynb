# %%
from pandas import read_csv
import pandas as pd
data = read_csv("data/caPowerPlants.csv")
data['location']= data['PLANT_CITY'] + "+" + data['PLANT_STATE']
data.head()
# Out:
#    OBJECTID     PLANT_NAME    COUNTY  ONLINE_MW       FACILITY GENERAL_FUEL  \
# 0         1     FALL CREEK  SISKIYOU        2.2  HYDROELECTRIC        HYDRO
# 1         2        COPCO 1  SISKIYOU       20.0  HYDROELECTRIC        HYDRO
# 2         3        COPCO 2  SISKIYOU       27.0  HYDROELECTRIC        HYDRO
# 3         4      IRON GATE  SISKIYOU       18.0  HYDROELECTRIC        HYDRO
# 4         5  PRATHER CREEK  SISKIYOU        0.1  HYDROELECTRIC        HYDRO
#
#   PRIMARY_FUEL                        TECHNOLOGY       STATUS  \
# 0        WATER                             HYDRO  OPERATIONAL
# 1        WATER  HYDRAULIC TURBINE - CONVENTIONAL  OPERATIONAL
# 2        WATER  HYDRAULIC TURBINE - CONVENTIONAL  OPERATIONAL
# 3        WATER                             HYDRO  OPERATIONAL
# 4        WATER                               NaN  OPERATIONAL
#
#            TURBINE_MW ONLINE_DATE PLANT_CITY PLANT_STATE PLANT_ZIPC  \
# 0  1=.5, 2=.05, 3=1.2      9/1/03  HORNBROOK          CA      96044
# 1        11=10, 12=10      1/1/18   MONTAGUE          CA      96044
# 2      1=13.5, 2=13.5      7/1/25   MONTAGUE          CA      96044
# 3                 NaN      2/1/62  HORNBROOK          CA      96044
# 4                 NaN      7/1/83    MACDOEL          CA      96058
#
#     RIVER_SYSTEM                        STREAM_NAME   DEVELOPER    ELEVATION  \
# 0  KLAMATH RIVER         JENNY CREEK, KLAMATH RIVER  PACIFICORP   768.816834
# 1  KLAMATH RIVER      KLAMATH RIVER,COPCO RESERVOIR  PACIFICORP   770.507935
# 2  KLAMATH RIVER      KLAMATH RIVER,COPCO RESERVOIR  PACIFICORP   715.878906
# 3  KLAMATH RIVER                      KLAMATH RIVER  PACIFICORP   667.581848
# 4   SHASTA RIVER  PRATHER CREEK, LOWER SHASTA RIVER   TKO POWER  1299.841064
#
#        location
# 0  HORNBROOK+CA
# 1   MONTAGUE+CA
# 2   MONTAGUE+CA
# 3  HORNBROOK+CA
# 4    MACDOEL+CA

# %% [markdown]
# ### Clears out all non string elements in location:

# %%
toDrop = []
for i in range(len(data)):
    if (type(data.ix[i].PLANT_CITY) is float):
       toDrop.append(i) 
toDrop
data = data.drop(toDrop)
len(data)
# Out:
# 1283

# %% [markdown]
# ---
# ## The function to pull lat lon from geocoder api

# %%
import requests
import json

def make_api_string(term):
    res = term.replace(", ","+")
    return res

def geolocations(city):
    """Give me a city string and I will give you the lat and lon coordinates of it.
    """
    API_KEY = "AIzaSyByolaM8l2clFXLvBhaIRE3daYbFwK8l4Y"
    #API_KEY = "AIzaSyAlZWYqyiQEa-FCgJ9Fo9b_GuceHR6yZVw"

    #The standard JSON call function doesnt work so I made an ugly one, Luckily were only doing one thing with the api.
    url_call = "https://maps.googleapis.com/maps/api/geocode/json?address=%s&sensor=false&key=%s" % (make_api_string(city), API_KEY)
    r = requests.get(url_call) 
    results = json.loads(r.text)

    lat = results['results'][0]['geometry']['location']['lat'] #Why oh why so many dictionaries?!
    lon = results['results'][0]['geometry']['location']['lng']
    return [lon,lat]

# %% [markdown]
# ---
# ### Testing out the geolocator function:

# %%
geolocations("ANN ARBOR MI")
# Out:
# [-83.7430378, 42.2808256]

# %% [markdown]
# ---
# ### The loop to append the lat lon data for locations:

# %%
latlons = []

for entry in data['location']: 
    try: 
        latLon = geolocations(entry)
    except:
        latLon = "NA"
    
    latlons.append(latLon)

data.head()
# Out:
#    OBJECTID     PLANT_NAME    COUNTY  ONLINE_MW       FACILITY GENERAL_FUEL  \
# 0         1     FALL CREEK  SISKIYOU        2.2  HYDROELECTRIC        HYDRO
# 1         2        COPCO 1  SISKIYOU       20.0  HYDROELECTRIC        HYDRO
# 2         3        COPCO 2  SISKIYOU       27.0  HYDROELECTRIC        HYDRO
# 3         4      IRON GATE  SISKIYOU       18.0  HYDROELECTRIC        HYDRO
# 4         5  PRATHER CREEK  SISKIYOU        0.1  HYDROELECTRIC        HYDRO
#
#   PRIMARY_FUEL                        TECHNOLOGY       STATUS  \
# 0        WATER                             HYDRO  OPERATIONAL
# 1        WATER  HYDRAULIC TURBINE - CONVENTIONAL  OPERATIONAL
# 2        WATER  HYDRAULIC TURBINE - CONVENTIONAL  OPERATIONAL
# 3        WATER                             HYDRO  OPERATIONAL
# 4        WATER                               NaN  OPERATIONAL
#
#            TURBINE_MW ONLINE_DATE PLANT_CITY PLANT_STATE PLANT_ZIPC  \
# 0  1=.5, 2=.05, 3=1.2      9/1/03  HORNBROOK          CA      96044
# 1        11=10, 12=10      1/1/18   MONTAGUE          CA      96044
# 2      1=13.5, 2=13.5      7/1/25   MONTAGUE          CA      96044
# 3                 NaN      2/1/62  HORNBROOK          CA      96044
# 4                 NaN      7/1/83    MACDOEL          CA      96058
#
#     RIVER_SYSTEM                        STREAM_NAME   DEVELOPER    ELEVATION  \
# 0  KLAMATH RIVER         JENNY CREEK, KLAMATH RIVER  PACIFICORP   768.816834
# 1  KLAMATH RIVER      KLAMATH RIVER,COPCO RESERVOIR  PACIFICORP   770.507935
# 2  KLAMATH RIVER      KLAMATH RIVER,COPCO RESERVOIR  PACIFICORP   715.878906
# 3  KLAMATH RIVER                      KLAMATH RIVER  PACIFICORP   667.581848
# 4   SHASTA RIVER  PRATHER CREEK, LOWER SHASTA RIVER   TKO POWER  1299.841064
#
#        location
# 0  HORNBROOK+CA
# 1   MONTAGUE+CA
# 2   MONTAGUE+CA
# 3  HORNBROOK+CA
# 4    MACDOEL+CA

# %% [markdown]
# ---
# ## Run through database and grab the latlons:

# %%
lats = []
lons = []
for entry in latlons:
    lons.append(entry[0])
    lats.append(entry[1])

data['lat'] = lats
data['lon'] = lons 

data.head()
# Out:
#    OBJECTID     PLANT_NAME    COUNTY  ONLINE_MW       FACILITY GENERAL_FUEL  \
# 0         1     FALL CREEK  SISKIYOU        2.2  HYDROELECTRIC        HYDRO
# 1         2        COPCO 1  SISKIYOU       20.0  HYDROELECTRIC        HYDRO
# 2         3        COPCO 2  SISKIYOU       27.0  HYDROELECTRIC        HYDRO
# 3         4      IRON GATE  SISKIYOU       18.0  HYDROELECTRIC        HYDRO
# 4         5  PRATHER CREEK  SISKIYOU        0.1  HYDROELECTRIC        HYDRO
#
#   PRIMARY_FUEL                        TECHNOLOGY       STATUS  \
# 0        WATER                             HYDRO  OPERATIONAL
# 1        WATER  HYDRAULIC TURBINE - CONVENTIONAL  OPERATIONAL
# 2        WATER  HYDRAULIC TURBINE - CONVENTIONAL  OPERATIONAL
# 3        WATER                             HYDRO  OPERATIONAL
# 4        WATER                               NaN  OPERATIONAL
#
#            TURBINE_MW         ...         PLANT_STATE PLANT_ZIPC  \
# 0  1=.5, 2=.05, 3=1.2         ...                  CA      96044
# 1        11=10, 12=10         ...                  CA      96044
# 2      1=13.5, 2=13.5         ...                  CA      96044
# 3                 NaN         ...                  CA      96044
# 4                 NaN         ...                  CA      96058
#
#     RIVER_SYSTEM                        STREAM_NAME   DEVELOPER    ELEVATION  \
# 0  KLAMATH RIVER         JENNY CREEK, KLAMATH RIVER  PACIFICORP   768.816834
# 1  KLAMATH RIVER      KLAMATH RIVER,COPCO RESERVOIR  PACIFICORP   770.507935
# 2  KLAMATH RIVER      KLAMATH RIVER,COPCO RESERVOIR  PACIFICORP   715.878906
# 3  KLAMATH RIVER                      KLAMATH RIVER  PACIFICORP   667.581848
# 4   SHASTA RIVER  PRATHER CREEK, LOWER SHASTA RIVER   TKO POWER  1299.841064
#
#        location                     latlons        lat         lon
# 0  HORNBROOK+CA  [-122.5558584, 41.9101394]  41.910139 -122.555858
# 1   MONTAGUE+CA  [-122.5278007, 41.7281985]  41.728198 -122.527801
# 2   MONTAGUE+CA  [-122.5278007, 41.7281985]  41.728198 -122.527801
# 3  HORNBROOK+CA  [-122.5558584, 41.9101394]  41.910139 -122.555858
# 4    MACDOEL+CA  [-122.0052851, 41.8268154]  41.826815 -122.005285
#
# [5 rows x 22 columns]

# %%
data.to_csv('data/caPowerPlantData.csv')

# %%
data = data.drop("COUNTY",1)
data = data.drop("OBJECTID",1)
data = data.drop("GENERAL_FUEL",1)
data = data.drop("TURBINE_MW",1)
data = data.drop("PLANT_STATE",1)
data = data.drop("PLANT_ZIPC",1)
data = data.drop("RIVER_SYSTEM",1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-5faef222c521> in <module>()
# ----> 1 data = data.drop("COUNTY",1)
#       2 data = data.drop("OBJECTID",1)
#       3 data = data.drop("GENERAL_FUEL",1)
#       4 data = data.drop("TURBINE_MW",1)
#       5 data = data.drop("PLANT_STATE",1)
#
# /Users/nstrayer/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, **kwargs)
#    1462                 new_axis = axis.drop(labels, level=level)
#    1463             else:
# -> 1464                 new_axis = axis.drop(labels)
#    1465             dropped = self.reindex(**{axis_name: new_axis})
#    1466             try:
#
# /Users/nstrayer/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/index.pyc in drop(self, labels)
#    1829         mask = indexer == -1
#    1830         if mask.any():
# -> 1831             raise ValueError('labels %s not contained in axis' % labels[mask])
#    1832         return self.delete(indexer)
#    1833
#
# ValueError: labels ['COUNTY'] not contained in axis

# %%
data = data.drop("PLANT_CITY",1)

data.head()
# Out:
#       PLANT_NAME  ONLINE_MW       FACILITY PRIMARY_FUEL  \
# 0     FALL CREEK        2.2  HYDROELECTRIC        WATER
# 1        COPCO 1       20.0  HYDROELECTRIC        WATER
# 2        COPCO 2       27.0  HYDROELECTRIC        WATER
# 3      IRON GATE       18.0  HYDROELECTRIC        WATER
# 4  PRATHER CREEK        0.1  HYDROELECTRIC        WATER
#
#                          TECHNOLOGY       STATUS ONLINE_DATE      location  \
# 0                             HYDRO  OPERATIONAL      9/1/03  HORNBROOK+CA
# 1  HYDRAULIC TURBINE - CONVENTIONAL  OPERATIONAL      1/1/18   MONTAGUE+CA
# 2  HYDRAULIC TURBINE - CONVENTIONAL  OPERATIONAL      7/1/25   MONTAGUE+CA
# 3                             HYDRO  OPERATIONAL      2/1/62  HORNBROOK+CA
# 4                               NaN  OPERATIONAL      7/1/83    MACDOEL+CA
#
#          lat         lon
# 0  41.910139 -122.555858
# 1  41.728198 -122.527801
# 2  41.728198 -122.527801
# 3  41.910139 -122.555858
# 4  41.826815 -122.005285

# %%
data.to_csv('latLonIfiedData.csv')
