# %% [markdown]
# #Making a D3.js driven flouroscope:
# ---
#
# ---
#
# ## Summary:
# 1. Get data in the form you want. Organized as an array/listof js objects. Cleaned, as trim as possible and with lat lon info.
# 2. Choose the style vis you want (currently node or hexbined heatmap.
# 3. Make sure the names of the statistic you are using (if more than just location) is properly named in the code.
# 4. Add interaction if wanted (mouseover, mouseout, click)
# 5. Profit...
#
# ---
# ##Things of note:
#
# ###Data format:
#
# Currently the webthing implimentation takes data in the form of a javascript object shoved in its own seperate .js file called in the html, this avoids asynchronicity and also I can't figure out how to access csvs. I use [this](http://www.convertcsv.com/csv-to-json.htm) to convert data to the right format, then copy and paste into the .js file.
#
# ###Location order:
# D3 is a lon lat kinda gal. (x,y) $\Longleftrightarrow$ (lon,lat). Remember this order and you're golden.
#
# ###Data Labeling:
# You can label location info "lon" "lat" for the node based visualizations, but for the hexbins, due to a need from the d3.hexbin library, they need to be [0] for lon [1] for lat.
# (This is because you feed d3.hexbin() an array with lon lat in it, it expects a simple array of arrays so it calls array[i][0], array[i+1][0] etc. In case you were wondering.
#
# ### More than just location?
# If your data has more variables than simply location you should label that whatever you need. Stat is a useful name if there is a single value.
#
# ###Need to grab lat lons from addresses, landmarks etc?
# Use this handi-dandy geocoding function. You should probably use [Charles' superior version](https://bitbucket.org/sbmct/sluice-demo-telecon/src/680e23d703803950c6b53689d0c253ac4ed4def3/lib/python/telecon/geo_lookup.py?at=feature/phase3) though...

# %%
import requests
import json

def make_api_string(term):
    res = term.replace(", ","+")
    return res

def geolocations(city):
    """Give me a city string and I will give you the lat and lon coordinates of it.
    """
    try:
        API_KEY = "AIzaSyByolaM8l2clFXLvBhaIRE3daYbFwK8l4Y"
        #API_KEY = "AIzaSyAlZWYqyiQEa-FCgJ9Fo9b_GuceHR6yZVw"

        #The standard JSON call function doesnt work so I made an ugly one, Luckily were only doing one thing with the api.
        url_call = "https://maps.googleapis.com/maps/api/geocode/json?address=%s&sensor=false&key=%s" % (make_api_string(city), API_KEY)
        r = requests.get(url_call) 
        results = json.loads(r.text)

        lat = results['results'][0]['geometry']['location']['lat'] #Why oh why so many dictionaries?!
        lon = results['results'][0]['geometry']['location']['lng']
        return [lon,lat]
    except:
        return [0,0]

# %% [markdown]
# ##Example of what data would look like (Solar radiation data.)

# %%
from pandas import read_csv
import pandas as pd
data = read_csv("hexbinSolarLevels/solarLevelsHexbin.csv")
data.head()
# Out:
#    Unnamed: 0          0          1  annualAverage
# 0           0 -86.499655  32.579182           4.46
# 1           1 -87.776333  30.601074           4.57
# 2           2 -85.354965  31.817290           4.58
# 3           3 -87.142289  32.956280           4.42
# 4           4 -86.499655  34.014515           4.28

# %% [markdown]
# # Now you have your data, let's draw some DOM.
# ---
#
# ##How it works:
# Sluice feeds the webflouroscope information on the boundries. These boundries are then used to draw a projection map projection with d3. The WebThing moves, the projection updates.
#
# The lon lat values are fed into a projection function and it spits out the x,y coordinates. The data is then plotted like a scatter plot.
#
# ---
# #Nodes:
#
# ###Initialize:
#     var svg = d3.select("body").append("svg")     //1
#
#     ...
#
#     var g = svg.append("g");    //2
#
#     g.selectAll("circle") //Append some svg circles to the DOM.      //3
# 	      .data(theData)      //4
# 	      .enter()
# 	      .append("circle")		//5
# 	      .attr("r", 5)
# 	      .attr("fill","blue")
# 	      .attr("cx",function(d){
# 	        return projection([d.lon, d.lat])[0]
# 	      })
# 	      .attr("cy",function(d){
# 	        return projection([d.lon, d.lat])[1]   //6
# 	      })
# 	      .on("mouseover",function(d){             //7
# 	        d3.select(this)
# 	          .attr("r",15)
# 	      })
# 	      .on("mouseout",function(d){
# 	        d3.select(this)
# 	          .attr("r",2)
# 	      })
#
#
# 1. d3 adds an SVG image to the dom (properties controlled by css but could be with .attr(__))
# 2. Add a "g" element inside of that svg.
# 3. Select all the circles (there arent any yet but this is d3's syntax)
# 4. Bind those selections with the data
# 5. Append a circle element for each data point
# 6. The properties are based upon the data (d) is the element of the data list d3 is currently dealing with.
# 7. Adds some interactivity.
#
# ###Update:
#
#      d3.selectAll("circle")
#           .data(theData)
#           .attr("cx",function(d){ //1
#             return projection([d.lon, d.lat])[0]
#           })
#           .attr("cy",function(d){
#             return projection([d.lon, d.lat])[1]
#           })
#
# 1. Update the positions of the cirlces with the newly computed projection.
#
# __Note:__ This method keeps the nodes the same size relative to the screen at all times. If you want the nodes to "stick" to the map, i.e. get bigger when zoomed or smaller when zoomed out, make the update the way hexbins does it.
#
# ---
# #Hexbins:
#
# ###Initialize:
#
#     var hexRadius = 15 //1
#
#     var hexbin = d3.hexbin() //2
#         .size([width, height])
#         .radius(hexRadius);
#
#     var brightness = d3.scale.sqrt() //3
#     .domain( [2, 8.2] ) //hard coded max values, should probably be added automatically.
#     .range(["black", "gold"])
#
#     data.forEach(function(d){  //4
# 	    var p = projection(d);
# 	    d[0] = p[0], d[1] = p[1];
# 	  });
#
# 	svg.append("g")                    //5
# 	      .attr("class", "hexagons")
# 	    .selectAll("path")
# 	      .data(hexbin(data).sort(function(a,b){return b.length - a.length; }))
# 	    .enter().append("path")
# 	      .attr("d", hexbin.hexagon(0.1))
# 	      .attr("transform", function(d) {return "translate(" + d.x + "," + d.y + ")"; })
# 	      .style("fill", function(d){ return brightness(d3.mean(d, function(d){return +d.annualAverage; }))})
# 	      //.style("fill-opacity", 0.8)
# 	      .on("mouseover", function(d){
# 	          d3.select(this)
# 	            .transition()
# 	            .duration(50)
# 	            .style("fill", "blue")
# 	      })
# 	      .on("mouseout", function(d){
# 	          d3.select(this)
# 	            .transition()
# 	            .duration(2500)
# 	            .style("fill", function(d){ return brightness(d3.mean(d, function(d){return +d.annualAverage; }))})
# 	      })
# 	      .transition()    //useless, but pretty enter animation.
# 	      .duration(1000)
# 	      .attr("d", hexbin.hexagon(hexRadius - 1))
#
#      oldUpperLeft   = upperLeft; //upper left in pixels  Needed for scaling and transforming later.  //6
# 	 oldBottomRight = bottomRight;//bottom right ""
#
# 1. Set size of hexbins.
# 2. Set up hexbin to browser window (if the size of the window ends up changing this will have to be re-initialized.)
# 3. Function to choose temperature. Gold = more sunlight
# 4. Convert the latlon points ([0] is lon) to xy coordinates to draw. Hexbins is not a geospacial specific package.
# 5. The hexbins function sets everything up for you and you simply have to let it do its thing. It creates a data array that has path info for each hexagon and other info about it such as number of elements (d.length).
# 6. We record the original x and y position for use in the scaling later.
#
# ### Zooming and panning/updating:
# Zooming and panning are all controled by this little snippit:
#
#         var xTrans   = (projection(oldUpperLeft)[0] - projection(upperLeft)[0]),
#             yTrans   = (projection(oldUpperLeft)[1] - projection(upperLeft)[1] ),                //1
#             orgXDif  = (projection(oldBottomRight)[0] - projection(oldUpperLeft)[0]),
#             orgYDif  = (projection(oldBottomRight)[1] - projection(oldUpperLeft)[1] ),           //2
#             xDif     = (projection(bottomRight)[0]    - projection(upperLeft)[0]),
#             yDif     = (projection(bottomRight)[1]    - projection(upperLeft)[1] ),              //3
#             transVal = [xTrans,yTrans],
#             scaleVal = (orgXDif/xDif);                                                           //4
#
#         d3.selectAll(".hexagons")                                                                //5
# 	      .attr("transform","translate(" + transVal.join(",") + ")scale(" + scaleVal +")");      //6
#
#
# 1. These are the distances in x,y that the maps upper left corner is away from its original position, in pixels. It takes the original corner and runs it through the current projection and compares those values with the newly positioned corner.
#
# 2. The distances, in pixels, between the corners of the flouroscope. These values are used in conjunction with...
#
# 3. ...to calculate the zoom level:
#
# 4. I.e. if the current distance is half the original then the scaleVal or zoom-level is set to 2.
#
# 5. Selects the g element clased as "hexagons..." (note: this will change depending on vis type, just make sure it contains your elements.)
#
# 6. ...and applies this transformation to it. [.join() because transVal is a list].
