# %% [markdown]
# #Nuclear Plants Around the World:
#
# ---
# note: Location = lat, lon
#
# ### Data: http://www.world-nuclear.org/

# %%
from pandas import read_csv
import pandas as pd
data = read_csv("nuclearReactorsWorld.csv")
data.head()
# Out:
#    Unnamed: 0              Facility             Location   Process  \
# 0           0              Atucha-1   -33.9669, -59.2086      PHWR
# 1           1               Embalse   -32.2315, -64.4423      PHWR
# 2           2  Armenia-2 (Metsamor)     40.1813, 44.1472  PWR/VVER
# 3           3                Doel-1     51.3227, 4.25868       PWR
# 4           4                Doel-2     51.3227, 4.25919       PWR
#
#    Capacity MWe net Current Status  Start Year  \
# 0               335      Operating        1974
# 1               600      Operating        1984
# 2               376      Operating        1980
# 3               392      Operating        1975
# 4               392      Operating        1975
#
#                                      Owner    Country ISO country code  \
# 0             Nucleoelectrica Argentina SA  Argentina               AR
# 1             Nucleoelectrica Argentina SA  Argentina               AR
# 2                          JSC Armenia NPP    Armenia               AM
# 3  Indivision Doel (EBES, INTERCOM, UNERG)    Belgium               BE
# 4  Indivision Doel (EBES, INTERCOM, UNERG)    Belgium               BE
#
#         lon      lat
# 0 -59.20860 -33.9669
# 1 -64.44230 -32.2315
# 2  44.14720  40.1813
# 3   4.25868  51.3227
# 4   4.25919  51.3227

# %%
len(data)
# Out:
# 442

# %%
#fix the decimal places yo: 
data.lon = [eval("%.1f" % entry) for entry in data.lon] #not sure if responsible (-,-)
data.lat = [eval("%.1f" % entry) for entry in data.lat] #                       
data.head()
# Out:
#     Unnamed: 0              Facility             Location   Process  \
# 0            0              Atucha-1   -33.9669, -59.2086      PHWR
# 1            1               Embalse   -32.2315, -64.4423      PHWR
# 2            2  Armenia-2 (Metsamor)     40.1813, 44.1472  PWR/VVER
# 6            6                Doel-4     51.3249, 4.25708       PWR
# 11          11               Angra-2   -23.0065, -44.4578       PWR
#
#     Capacity MWe net Current Status  Start Year  \
# 0                335      Operating        1974
# 1                600      Operating        1984
# 2                376      Operating        1980
# 6               1001      Operating        1985
# 11              1270      Operating        2001
#
#                                       Owner    Country ISO country code   lon  \
# 0              Nucleoelectrica Argentina SA  Argentina               AR -59.2
# 1              Nucleoelectrica Argentina SA  Argentina               AR -64.4
# 2                           JSC Armenia NPP    Armenia               AM  44.1
# 6   Indivision Doel (EBES, INTERCOM, UNERG)    Belgium               BE   4.3
# 11                            Eletronuclear     Brazil               BR -44.5
#
#      lat
# 0  -34.0
# 1  -32.2
# 2   40.2
# 6   51.3
# 11 -23.0

# %%
data = data.drop_duplicates(cols = "lon",take_last=True)
len(data)
#data.head()
data.to_csv('nuclearReactorsWorld.csv')

# %%
data["lon"] = [eval(entry)[1] for entry in data.Location]
data["lat"] = [eval(entry)[0] for entry in data.Location]
data.head()
# Out:
#                Facility             Location   Process  Capacity MWe net  \
# 0              Atucha-1   -33.9669, -59.2086      PHWR               335
# 1               Embalse   -32.2315, -64.4423      PHWR               600
# 2  Armenia-2 (Metsamor)     40.1813, 44.1472  PWR/VVER               376
# 3                Doel-1     51.3227, 4.25868       PWR               392
# 4                Doel-2     51.3227, 4.25919       PWR               392
#
#   Current Status  Start Year                                    Owner  \
# 0      Operating        1974             Nucleoelectrica Argentina SA
# 1      Operating        1984             Nucleoelectrica Argentina SA
# 2      Operating        1980                          JSC Armenia NPP
# 3      Operating        1975  Indivision Doel (EBES, INTERCOM, UNERG)
# 4      Operating        1975  Indivision Doel (EBES, INTERCOM, UNERG)
#
#      Country ISO country code       lon      lat
# 0  Argentina               AR -59.20860 -33.9669
# 1  Argentina               AR -64.44230 -32.2315
# 2    Armenia               AM  44.14720  40.1813
# 3    Belgium               BE   4.25868  51.3227
# 4    Belgium               BE   4.25919  51.3227

# %%
import string
exclude = set(string.punctuation) #a list of punctuation

fixedLocs = []
dispLocs = []
for i in range(len(df)):
    string = df.ix[i].location
    where = string.index('(') #Get rid of the qualitative discriptions
    string = string[:where - 1]
    
    dispLocs.append(string)
    
    newString = ''.join(ch for ch in string if ch not in exclude) #Get rid of punctuation
    
    newString = newString.replace("   ","+") #Puts location into geolocationAPi friendly format 
    newString = newString.replace("  ","+")
    newString = newString.replace(" ","+")
    
    fixedLocs.append(newString)

fixedLocs
#dispLocs
# Out:
# ['London+AR',
#  'London+AR',
#  'Shippingport+P',
#  'Shippingport+PA',
#  'Braceville+IL',
#  'Braceville+IL',
#  'Limestone+County+AL',
#  'Limestone+County+AL',
#  'Limestone+County+AL',
#  'Southport+NC',
#  'Southport+NC',
#  'Byron+Il',
#  'Byron+Il',
#  'Fulton+MO',
#  'Lusby+MD',
#  'Lusby+MD',
#  'York+SC',
#  'York+SC',
#  'Clinton+IL',
#  'Richland+WA',
#  'Glen+Rose+TX',
#  'Glen+Rose+TX',
#  'Brownville+NE',
#  'Oak+Harbor+OH',
#  'Avila+Beach+CA',
#  'Avila+Beach+CA',
#  'Bridgman+MI',
#  'Bridgman+MI',
#  'Morris+IL',
#  'Morris+IL',
#  'Palo+IA',
#  'Baxley+GA',
#  'Baxley+GA',
#  'Newport+MI',
#  'Fort+Calhoun+NE',
#  'Port+Gibson+MS',
#  'Hartsville+SC',
#  'Hancocks+Bridge+NJ',
#  'Buchanan+NY',
#  'Buchanan+NY',
#  'Scriba+NY',
#  'Columbia+AL',
#  'Columbia+AL',
#  'Marseilles+IL',
#  'Marseilles+IL',
#  'Limerick+PA',
#  'Limerick+PA',
#  'Huntersville+NC',
#  'Huntersville+NC',
#  'Waterford+CT',
#  'Waterford+CT',
#  'Monticello+MN',
#  'Scriba+NY',
#  'Scriba+NY',
#  'Mineral',
#  'Mineral',
#  'Seneca+SC',
#  'Seneca+SC',
#  'Seneca+SC',
#  'Forked+River+NJ',
#  'Covert+MI',
#  'Wintersburg+AZ',
#  'Wintersburg+AZ',
#  'Wintersburg+AZ',
#  'Delta+PA',
#  'Delta+PA',
#  'Perry+OH',
#  'Plymouth+MA',
#  'Two+Rivers+WI',
#  'Two+Rivers+WI',
#  'Welch+MN',
#  'Welch+MN',
#  'Cordova+IL',
#  'Cordova+IL',
#  'St+Francisville+LA',
#  'Ontario+NY',
#  'Jensen+Beach+FL',
#  'Jensen+Beach+FL',
#  'Hancocks+Bridge+NJ',
#  'Hancocks+Bridge+NJ',
#  'Seabrook+NH',
#  'SoddyDaisy+TN',
#  'SoddyDaisy+TN',
#  'New+Hill+NC',
#  'Bay+City+TX',
#  'Bay+City+TX',
#  'Surry+VA',
#  'Surry+VA',
#  'Salem+Township+Luzerne+Co+PA',
#  'Salem+Township+Luzerne+Co+PA',
#  'Middletown+PA',
#  'Homestead+FL',
#  'Homestead+FL',
#  'Vernon+VT',
#  'Jenkinsville+SC',
#  'Waynesboro+GA',
#  'Waynesboro+GA',
#  'Killona+LA',
#  'Spring+City+TN',
#  'Burlington']

# %%
df.location = fixedLocs
df.displayLocations = dispLocs
df.head()
# Out:
#                                  plant         location  capacity lonlats  \
# 0         Arkansas Nuclear One, Unit 1        London+AR    2568.0     NaN
# 1         Arkansas Nuclear One, Unit 2        London+AR    3026.0     NaN
# 2  Beaver Valley Power Station, Unit 1   Shippingport+P    2900.0     NaN
# 3  Beaver Valley Power Station, Unit 2  Shippingport+PA    2900.0     NaN
# 4            Braidwood Station, Unit 1    Braceville+IL    3586.6     NaN
#
#    displayLocations
# 0        London, AR
# 1        London, AR
# 2   Shippingport, P
# 3  Shippingport, PA
# 4    Braceville, IL

# %%
import requests
import json

def make_api_string(term):
    res = term.replace(", ","+")
    return res

def geolocations(city):
    """Give me a city string and I will give you the lat and lon coordinates of it.
    """
    try:
        API_KEY = "AIzaSyByolaM8l2clFXLvBhaIRE3daYbFwK8l4Y"
        #API_KEY = "AIzaSyAlZWYqyiQEa-FCgJ9Fo9b_GuceHR6yZVw"

        #The standard JSON call function doesnt work so I made an ugly one, Luckily were only doing one thing with the api.
        url_call = "https://maps.googleapis.com/maps/api/geocode/json?address=%s&sensor=false&key=%s" % (make_api_string(city), API_KEY)
        r = requests.get(url_call) 
        results = json.loads(r.text)

        lat = results['results'][0]['geometry']['location']['lat'] #Why oh why so many dictionaries?!
        lon = results['results'][0]['geometry']['location']['lng']
        return [lon,lat]
    except:
        return [0,0]

# %%
df.lonlats = [geolocations(place) for place in df.location]

# %%
df.head()
# Out:
#                                  plant         location  capacity  \
# 0         Arkansas Nuclear One, Unit 1        London+AR    2568.0
# 1         Arkansas Nuclear One, Unit 2        London+AR    3026.0
# 2  Beaver Valley Power Station, Unit 1   Shippingport+P    2900.0
# 3  Beaver Valley Power Station, Unit 2  Shippingport+PA    2900.0
# 4            Braidwood Station, Unit 1    Braceville+IL    3586.6
#
#                      lonlats  displayLocations
# 0   [-93.2529553, 35.328973]        London, AR
# 1   [-93.2529553, 35.328973]        London, AR
# 2  [-80.4139539, 40.6320101]   Shippingport, P
# 3  [-80.4139539, 40.6320101]  Shippingport, PA
# 4  [-88.2647833, 41.2269765]    Braceville, IL

# %%
df.to_csv('data/nuclearPowerPlants.csv')

# %%
data['lonlats'] = latlons

# %%
data = data.drop("latlons",1)

# %%
data.head()
# Out:
#    Year Report\r\nState           Plant Name  \
# 0  2012              AL         Atmore Plant
# 1  2012              AL   Big Escambia Creek
# 2  2012              AL    Castleberry Plant
# 3  2012              AL         Chatom Plant
# 4  2012              AL  Chunchula Gas Plant
#
#                            Owner Company                   Operator Company  \
# 0  American Midstream (Mississippi), LLC                 American Midstream
# 1        Escambia Operating Company, LLC       Eagle Rock Energy G & P, LLC
# 2                                    NaN                Gas Processors, Inc
# 3                                    NaN  Quantum Resources Management, LLC
# 4                    Chevron Corporation                Chevron Corporation
#
#   County Name Zipcode Plant\r\nCapacity Plant\r\nFlow BTU\r\nContent  \
# 0    Escambia   36502              3.00          1.15          1,218
# 1    Escambia   36502             50.00         48.00            900
# 2     Conecuh   36432              9.50          8.50          1,427
# 3  Washington   36518             25.00         13.80            117
# 4      Mobile   36521             40.00         15.60          1,079
#
#    Dry Gas\r\nStorage\r\nCapacity NG Liquid\r\nStorage\r\nCapacity  \
# 0                               0                              429
# 1                               0                           34,000
# 2                               0                            2,850
# 3                               0                            7,650
# 4                               0                           15,833
#
#                      lonlats
# 0   [-87.5000082, 31.101077]
# 1   [-87.5000082, 31.101077]
# 2  [-87.0824045, 31.2982897]
# 3  [-88.3433623, 31.4578061]
# 4  [-88.1876676, 30.9520403]

# %%
data.to_csv('data/natGasWells.csv')
